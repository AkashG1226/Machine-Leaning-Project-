# %% [markdown]
# <a href="https://colab.research.google.com/github/AkashG1226/Machine-Leaning-Project-/blob/main/data_frame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# data frame

# %%
import numpy as np
import pandas as pd
sales =pd.DataFrame({'id':[1001,1002,1003,1004,1005],
'NAME':['maverick','reoshan','sandy','captain',np.nan],
'amount':[10000,50000,30000,40000,60000],
'regain':['coimbatore','chennai','chennai','salem',np.nan]})
print(sales)
# Out:
#      id      NAME  amount      regain
# 0  1001  maverick   10000  coimbatore
# 1  1002   reoshan   50000     chennai
# 2  1003     sandy   30000     chennai
# 3  1004   captain   40000       salem
# 4  1005       NaN   60000         NaN

# %%
sales[sales['amount']>50000]
# Out:
#      id NAME  amount regain
# 4  1005  NaN   60000    NaN

# %%
np.abs(sales['amount'])
# Out:
# 0    10000
# 1    50000
# 2    30000
# 3    40000
# 4    60000
# Name: amount, dtype: int64

# %%
sales['regain'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: regain, dtype: bool

# %%
sales['regain'].isnull().sum()
# Out:
# np.int64(1)

# %%
sales.dropna()
# Out:
#      id      NAME  amount      regain
# 0  1001  maverick   10000  coimbatore
# 1  1002   reoshan   50000     chennai
# 2  1003     sandy   30000     chennai
# 3  1004   captain   40000       salem

# %%
sales.columns
# Out:
# Index(['id', 'NAME', 'amount', 'regain'], dtype='object')

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      5 non-null      int64
#  1   NAME    4 non-null      object
#  2   amount  5 non-null      int64
#  3   regain  4 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes

# %%
sales.describe()
# Out:
#                 id        amount
# count     5.000000      5.000000
# mean   1003.000000  38000.000000
# std       1.581139  19235.384062
# min    1001.000000  10000.000000
# 25%    1002.000000  30000.000000
# 50%    1003.000000  40000.000000
# 75%    1004.000000  50000.000000
# max    1005.000000  60000.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['id'].plot(kind='hist', bins=20, title='id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['amount'].plot(kind='hist', bins=20, title='amount')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
sales.ndim
# Out:
# 2

# %%
sales.shape
# Out:
# (5, 4)

# %%
sales.size
# Out:
# 20

# %%
sales.head(2)
# Out:
#      id      NAME  amount      regain
# 0  1001  maverick   10000  coimbatore
# 1  1002   reoshan   50000     chennai

# %%
sales.tail(1)
# Out:
#      id NAME  amount regain
# 4  1005  NaN   60000    NaN

# %%
sales1=pd.DataFrame({'id':[1001,1002,1003,1004],'dept':['sale','sales','marketing','hr']})
sales1
# Out:
#      id       dept
# 0  1001       sale
# 1  1002      sales
# 2  1003  marketing
# 3  1004         hr

# %%
sales[['id','amount']]
# Out:
#      id  amount
# 0  1001   10000
# 1  1002   50000
# 2  1003   30000
# 3  1004   40000
# 4  1005   60000

# %%
sales=pd.merge(sales,sales1,on='id')
sales
# Out:
#      id      NAME  amount      regain       dept
# 0  1001  maverick   10000  coimbatore       sale
# 1  1002   reoshan   50000     chennai      sales
# 2  1003     sandy   30000     chennai  marketing
# 3  1004   captain   40000       salem         hr

# %%
sales.drop(['id'],axis=1)
# Out:
#        NAME  amount      regain       dept
# 0  maverick   10000  coimbatore       sale
# 1   reoshan   50000     chennai      sales
# 2     sandy   30000     chennai  marketing
# 3   captain   40000       salem         hr

# %%
sales.drop(0)
# Out:
#      id     NAME  amount   regain       dept
# 1  1002  reoshan   50000  chennai      sales
# 2  1003    sandy   30000  chennai  marketing
# 3  1004  captain   40000    salem         hr

# %%
sales2=sales.drop([0,2])

# %%
sales2=sales.drop([3])

# %%
sales2
# Out:
#      id      NAME  amount      regain       dept
# 0  1001  maverick   10000  coimbatore       sale
# 1  1002   reoshan   50000     chennai      sales
# 2  1003     sandy   30000     chennai  marketing

# %%
sales.drop(sales[sales['id'] == 10001].index,inplace=True)
sales
# Out:
#      id      NAME  amount      regain       dept
# 0  1001  maverick   10000  coimbatore       sale
# 1  1002   reoshan   50000     chennai      sales
# 2  1003     sandy   30000     chennai  marketing
# 3  1004   captain   40000       salem         hr

# %%
sales=sales2.drop(1)

# %%
sales2
# Out:
#      id      NAME  amount      regain       dept
# 0  1001  maverick   10000  coimbatore       sale
# 1  1002   reoshan   50000     chennai      sales
# 2  1003     sandy   30000     chennai  marketing

# %%
sales['id'] = sales ['id'].replace(1004,1005)

# %%
sales
# Out:
#      id      NAME  amount      regain       dept
# 0  1001  maverick   10000  coimbatore       sale
# 2  1003     sandy   30000     chennai  marketing

# %%
sales['region'] = sales['regain'].replace('sale','trichy')

# %%
sales
# Out:
#      id      NAME  amount      regain       dept      redion      region
# 0  1001  maverick   10000  coimbatore       sale  coimbatore  coimbatore
# 2  1003     sandy   30000     chennai  marketing     chennai     chennai

# %%
sales2
# Out:
#      id      NAME  amount      regain       dept
# 0  1001  maverick   10000  coimbatore       sale
# 1  1002   reoshan   50000     chennai      sales
# 2  1003     sandy   30000     chennai  marketing
