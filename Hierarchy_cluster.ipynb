# %% [markdown]
# <a href="https://colab.research.google.com/github/AkashG1226/Machine-Leaning-Project-/blob/main/Hierarchy_cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
data=np.array([[18],[22],[25],[42],[27],[43]])
linkage = linkage(data, method='single')

# %%
plt.figure(figsize=(8, 5))

# %%
 dendrogram(linkage,
            orientation='top',
          labels=[18,22,25,42,27,43],
            distance_sort='ascending',
            show_leaf_counts=True)
 plt.title("Hierarchical Clustering Dendrogram")
 plt.xlabel("Data Points")
 plt.ylabel(" Distance")
 plt.grid(True)
 plt.show()
